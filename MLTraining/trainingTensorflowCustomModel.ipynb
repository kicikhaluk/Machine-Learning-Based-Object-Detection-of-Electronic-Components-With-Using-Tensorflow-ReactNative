# %%
# %tensorflow_version 1.x
# !pip install tf_slim
# Out:
# TensorFlow 1.x selected.
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from tf_slim) (0.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from absl-py>=0.2.2->tf_slim) (1.12.0)

# %%
from google.colab import drive
 
drive.mount('/gdrive')
# the project's folder
# %cd /gdrive/'My Drive'/object_detection
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/object_detection

# %%
# %cd /gdrive/'My Drive'/object_detection/data
# Out:
# /gdrive/My Drive/object_detection

# %%
# !git clone https://github.com/kicikhaluk/tezimages.git
# Out:
# Cloning into 'tezimages'...
# remote: Enumerating objects: 814, done.
# remote: Counting objects: 100% (814/814), done.
# remote: Compressing objects: 100% (499/499), done.
# remote: Total 814 (delta 317), reused 812 (delta 315), pack-reused 0
# Receiving objects: 100% (814/814), 4.13 MiB | 14.62 MiB/s, done.
# Resolving deltas: 100% (317/317), done.
# Checking out files: 100% (538/538), done.

# %%
# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk
# !pip install -qq Cython contextlib2 pillow lxml matplotlib pycocotools
# !pip install numpy==1.16
# Out:
# Requirement already satisfied: numpy==1.16 in /usr/local/lib/python3.6/dist-packages (1.16.0)

# %%
from __future__ import division, print_function, absolute_import

import pandas as pd
import numpy as np
import csv

import re
import os
import io
import glob
import shutil
import urllib.request
import tarfile
import xml.etree.ElementTree as ET

import tensorflow.compat.v1 as tf
import cv2 

from PIL import Image
from collections import namedtuple, OrderedDict

from google.colab import files

# %%
print(tf.__version__)
# Out:
# 1.15.2

# %%
#adjusted from: https://github.com/datitran/raccoon_dataset
def xml_to_csv(path):
  classes_names = []
  xml_list = []

  for xml_file in glob.glob(path + '/*.xml'):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    for member in root.findall('object'):
      classes_names.append(member[0].text)
      value = (root.find('filename').text,
               int(root.find('size')[0].text),
               int(root.find('size')[1].text),
               member[0].text,
               int(member[4][0].text),
               int(member[4][1].text),
               int(member[4][2].text),
               int(member[4][3].text))
      xml_list.append(value)
  column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
  xml_df = pd.DataFrame(xml_list, columns=column_name) 
  classes_names = list(set(classes_names))
  classes_names.sort()
  return xml_df, classes_names

for label_path in ['train_labels', 'test_labels']:
  image_path = os.path.join(os.getcwd(), label_path)
  xml_df, classes = xml_to_csv(label_path)
  xml_df.to_csv(f'{label_path}.csv', index=None)
  print(f'Successfully converted {label_path} xml to csv.')

label_map_path = os.path.join("label_map.pbtxt")
pbtxt_content = ""

for i, class_name in enumerate(classes):
    pbtxt_content = (
        pbtxt_content
        + "item {{\n    id: {0}\n    name: '{1}'\n}}\n\n".format(i + 1, class_name)
    )
pbtxt_content = pbtxt_content.strip()
with open(label_map_path, "w") as f:
    f.write(pbtxt_content)
# Out:
# Successfully converted train_labels xml to csv.
# Successfully converted test_labels xml to csv.

# %%
# %cd /gdrive/'My Drive'/object_detection/models/research
# Out:
# /gdrive/My Drive/object_detection/models/research

# %%
# compils the proto buffers
# !protoc object_detection/protos/*.proto --python_out=.
# exports PYTHONPATH environment var with research and slim paths
os.environ['PYTHONPATH'] += ':./:./slim/'
# Out:
# object_detection/protos/input_reader.proto: warning: Import object_detection/protos/image_resizer.proto but not used.

# %%
# testing the model builder
# !python3 object_detection/builders/model_builder_test.py

# %%
#adjusted from: https://github.com/datitran/raccoon_dataset
from object_detection.utils import dataset_util


#change this to the base directory where your data/ is 
data_base_url = '/gdrive/My Drive/object_detection/data/'

#location of images
image_dir = data_base_url +'images/'

def class_text_to_int(row_label):
  if row_label == 'resistor':
    return 1
  elif row_label == 'voltage':
    return 2
  else:
    None

def split(df, group):
  data = namedtuple('data', ['filename', 'object'])
  gb = df.groupby(group)
  return [data(filename, gb.get_group(x)) for filename, x in zip(gb.groups.keys(), gb.groups)]

def create_tf_example(group, path):

      with tf.io.gfile.GFile(os.path.join(path, '{}'.format(group.filename)), 'rb') as fid:
        encoded_jpg = fid.read()
      encoded_jpg_io = io.BytesIO(encoded_jpg)
      image = Image.open(encoded_jpg_io)
      width, height = image.size
      filename = group.filename.encode('utf8')
      image_format = b'jpg'
      xmins = []
      xmaxs = []
      ymins = []
      ymaxs = []
      classes_text = []
      classes = []

      for index, row in group.object.iterrows():
        xmins.append(row['xmin'] / width)
        xmaxs.append(row['xmax'] / width)
        ymins.append(row['ymin'] / height)
        ymaxs.append(row['ymax'] / height)
        classes_text.append(row['class'].encode('utf8'))
        classes.append(class_text_to_int(row['class']))

      tf_example = tf.train.Example(features=tf.train.Features(feature={
        'image/height': dataset_util.int64_feature(height),
        'image/width': dataset_util.int64_feature(width),
        'image/filename': dataset_util.bytes_feature(filename),
        'image/source_id': dataset_util.bytes_feature(filename),
        'image/encoded': dataset_util.bytes_feature(encoded_jpg),
        'image/format': dataset_util.bytes_feature(image_format),
        'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
        'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
        'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
        'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
        'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
        'image/object/class/label': dataset_util.int64_list_feature(classes),
        }))
      
      return tf_example

#creates tfrecord for both csv's
for csv in ['train_labels', 'test_labels']:
  writer = tf.io.TFRecordWriter(data_base_url + csv + '.record')
  path = os.path.join(image_dir)
  examples = pd.read_csv(data_base_url + csv + '.csv')
  grouped = split(examples, 'filename')
  for group in grouped:
    tf_example = create_tf_example(group, path)
    writer.write(tf_example.SerializeToString())
    
  writer.close()
  output_path = os.path.join(os.getcwd(), data_base_url + csv + '.record')
  print('Successfully created the TFRecords: {}'.format(data_base_url +csv + '.record'))
# Out:
# Successfully created the TFRecords: /gdrive/My Drive/object_detection/data/train_labels.record
# Successfully created the TFRecords: /gdrive/My Drive/object_detection/data/test_labels.record

# %%
# Some models to train on
MODELS_CONFIG = {
    'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
    },
    'faster_rcnn_inception_v2': {
        'model_name': 'faster_rcnn_inception_v2_coco_2018_01_28',
    },
}

# Select a model from `MODELS_CONFIG`.
# I chose ssd_mobilenet_v2 for this project, you could choose any
selected_model = 'ssd_mobilenet_v2'

# %%
# %cd /gdrive/My Drive/object_detection/models/research
# Out:
# /gdrive/My Drive/object_detection/models/research

# %%
#the distination folder where the model will be saved
#change this if you have a different working dir
DEST_DIR = '/gdrive/My Drive/object_detection/models/research/pretrained_model'

# Name of the object detection model to use.
MODEL = MODELS_CONFIG[selected_model]['model_name']

#selecting the model
MODEL_FILE = MODEL + '.tar.gz'

#creating the downlaod link for the model selected
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'

#checks if the model has already been downloaded, download it otherwise
if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

#unzipping the model and extracting its content
tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

# creating an output file to save the model while training
os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)

# %%
import time, psutil
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600)
# Out:
# Time remaining for this session is:  11.954685399863456

# %%
# !python3 object_detection/model_main.py \
    --pipeline_config_path=/gdrive/My\ Drive/object_detection/models/research/object_detection/samples/configs/ssd_mobilenet_v2_coco.config \
    --model_dir=training/
# Out:
# Streaming output truncated to the last 5000 lines.
# 2020-06-21 23:48:27.645943: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-21 23:48:27.645971: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-21 23:48:27.645994: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-21 23:48:27.646020: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-21 23:48:27.646043: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-21 23:48:27.646068: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-21 23:48:27.646182: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-21 23:48:27.646667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-21 23:48:27.647070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-06-21 23:48:27.647200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-06-21 23:48:27.647219: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-06-21 23:48:27.647229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-06-21 23:48:27.647346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-21 23:48:27.647837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-21 23:48:27.648355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-6057
# I0621 23:48:27.650357 140651608708992 saver.py:1284] Restoring parameters from training/model.ckpt-6057
# INFO:tensorflow:Running local_init_op.
# I0621 23:48:28.570142 140651608708992 session_manager.py:500] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0621 23:48:28.699429 140651608708992 session_manager.py:502] Done running local_init_op.
# INFO:tensorflow:Performing evaluation on 50 images.
# I0621 23:48:32.460224 140649450837760 coco_evaluation.py:237] Performing evaluation on 50 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0621 23:48:32.461411 140649450837760 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0621 23:48:32.464861 140649450837760 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.45s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.377
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.887
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.205
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.364
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.483
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.505
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.488
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.617
# INFO:tensorflow:Finished evaluation at 2020-06-21-23:48:33
# I0621 23:48:33.050695 140651608708992 evaluation.py:275] Finished evaluation at 2020-06-21-23:48:33
# INFO:tensorflow:Saving dict for global step 6057: DetectionBoxes_Precision/mAP = 0.37693876, DetectionBoxes_Precision/mAP (large) = 0.49229035, DetectionBoxes_Precision/mAP (medium) = 0.36371034, DetectionBoxes_Precision/mAP (small) = 0.477271, DetectionBoxes_Precision/mAP@.50IOU = 0.8871008, DetectionBoxes_Precision/mAP@.75IOU = 0.20538367, DetectionBoxes_Recall/AR@1 = 0.31832758, DetectionBoxes_Recall/AR@10 = 0.48313794, DetectionBoxes_Recall/AR@100 = 0.5008793, DetectionBoxes_Recall/AR@100 (large) = 0.6175, DetectionBoxes_Recall/AR@100 (medium) = 0.48752475, DetectionBoxes_Recall/AR@100 (small) = 0.505, Loss/classification_loss = 4.771078, Loss/localization_loss = 1.0438722, Loss/regularization_loss = 0.25718492, Loss/total_loss = 6.072137, global_step = 6057, learning_rate = 0.004, loss = 6.072137
# I0621 23:48:33.050998 140651608708992 estimator.py:2049] Saving dict for global step 6057: DetectionBoxes_Precision/mAP = 0.37693876, DetectionBoxes_Precision/mAP (large) = 0.49229035, DetectionBoxes_Precision/mAP (medium) = 0.36371034, DetectionBoxes_Precision/mAP (small) = 0.477271, DetectionBoxes_Precision/mAP@.50IOU = 0.8871008, DetectionBoxes_Precision/mAP@.75IOU = 0.20538367, DetectionBoxes_Recall/AR@1 = 0.31832758, DetectionBoxes_Recall/AR@10 = 0.48313794, DetectionBoxes_Recall/AR@100 = 0.5008793, DetectionBoxes_Recall/AR@100 (large) = 0.6175, DetectionBoxes_Recall/AR@100 (medium) = 0.48752475, DetectionBoxes_Recall/AR@100 (small) = 0.505, Loss/classification_loss = 4.771078, Loss/localization_loss = 1.0438722, Loss/regularization_loss = 0.25718492, Loss/total_loss = 6.072137, global_step = 6057, learning_rate = 0.004, loss = 6.072137
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6057: training/model.ckpt-6057
# I0621 23:48:33.853845 140651608708992 estimator.py:2109] Saving 'checkpoint_path' summary for global step 6057: training/model.ckpt-6057
# INFO:tensorflow:global_step/sec: 4.47711
# I0621 23:48:38.255491 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 4.47711
# INFO:tensorflow:loss = 2.6206505, step = 6100 (22.336 sec)
# I0621 23:48:38.257067 140651608708992 basic_session_run_hooks.py:260] loss = 2.6206505, step = 6100 (22.336 sec)
# INFO:tensorflow:global_step/sec: 10.0459
# I0621 23:48:48.209796 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.0459
# INFO:tensorflow:loss = 3.0950382, step = 6200 (9.954 sec)
# I0621 23:48:48.210866 140651608708992 basic_session_run_hooks.py:260] loss = 3.0950382, step = 6200 (9.954 sec)
# INFO:tensorflow:global_step/sec: 10.2044
# I0621 23:48:58.009496 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.2044
# INFO:tensorflow:loss = 4.174893, step = 6300 (9.800 sec)
# I0621 23:48:58.010415 140651608708992 basic_session_run_hooks.py:260] loss = 4.174893, step = 6300 (9.800 sec)
# INFO:tensorflow:global_step/sec: 10.2579
# I0621 23:49:07.758074 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.
140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.1567
# INFO:tensorflow:loss = 2.28045, step = 17200 (9.846 sec)
# I0622 00:06:42.279949 140651608708992 basic_session_run_hooks.py:260] loss = 2.28045, step = 17200 (9.846 sec)
# INFO:tensorflow:global_step/sec: 10.1589
# I0622 00:06:52.122452 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.1589
# INFO:tensorflow:loss = 3.0605187, step = 17300 (9.844 sec)
# I0622 00:06:52.123520 140651608708992 basic_session_run_hooks.py:260] loss = 3.0605187, step = 17300 (9.844 sec)
# INFO:tensorflow:global_step/sec: 10.1966
# I0622 00:07:01.929665 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.1966
# INFO:tensorflow:loss = 4.139126, step = 17400 (9.807 sec)
# I0622 00:07:01.930700 140651608708992 basic_session_run_hooks.py:260] loss = 4.139126, step = 17400 (9.807 sec)
# INFO:tensorflow:global_step/sec: 10.3581
# I0622 00:07:11.583939 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.3581
# INFO:tensorflow:loss = 3.1131861, step = 17500 (9.654 sec)
# I0622 00:07:11.585123 140651608708992 basic_session_run_hooks.py:260] loss = 3.1131861, step = 17500 (9.654 sec)
# INFO:tensorflow:global_step/sec: 10.1858
# I0622 00:07:21.401495 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.1858
# INFO:tensorflow:loss = 3.3258946, step = 17600 (9.818 sec)
# I0622 00:07:21.402625 140651608708992 basic_session_run_hooks.py:260] loss = 3.3258946, step = 17600 (9.818 sec)
# INFO:tensorflow:global_step/sec: 10.1718
# I0622 00:07:31.232550 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.1718
# INFO:tensorflow:loss = 3.6682322, step = 17700 (9.831 sec)
# I0622 00:07:31.233777 140651608708992 basic_session_run_hooks.py:260] loss = 3.6682322, step = 17700 (9.831 sec)
# INFO:tensorflow:global_step/sec: 10.2914
# I0622 00:07:40.949421 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.2914
# INFO:tensorflow:loss = 2.8187218, step = 17800 (9.717 sec)
# I0622 00:07:40.951032 140651608708992 basic_session_run_hooks.py:260] loss = 2.8187218, step = 17800 (9.717 sec)
# INFO:tensorflow:global_step/sec: 10.2566
# I0622 00:07:50.699256 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.2566
# INFO:tensorflow:loss = 3.3635685, step = 17900 (9.749 sec)
# I0622 00:07:50.700376 140651608708992 basic_session_run_hooks.py:260] loss = 3.3635685, step = 17900 (9.749 sec)
# INFO:tensorflow:global_step/sec: 10.2905
# I0622 00:08:00.416905 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.2905
# INFO:tensorflow:loss = 2.512323, step = 18000 (9.718 sec)
# I0622 00:08:00.418050 140651608708992 basic_session_run_hooks.py:260] loss = 2.512323, step = 18000 (9.718 sec)
# INFO:tensorflow:global_step/sec: 10.247
# I0622 00:08:10.175815 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.247
# INFO:tensorflow:loss = 3.3088408, step = 18100 (9.759 sec)
# I0622 00:08:10.176973 140651608708992 basic_session_run_hooks.py:260] loss = 3.3088408, step = 18100 (9.759 sec)
# INFO:tensorflow:global_step/sec: 10.31
# I0622 00:08:19.875095 140651608708992 basic_session_run_hooks.py:692] global_step/sec: 10.31
# INFO:tensorflow:loss = 2.6556213, step = 18200 (9.700 sec)
# I0622 00:08:19.876699 140651608708992 basic_session_run_hooks.py:260] loss = 2.6556213, step = 18200 (9.700 sec)
# INFO:tensorflow:Saving checkpoints for 18216 into training/model.ckpt.
# I0622 00:08:21.383612 140651608708992 basic_session_run_hooks.py:606] Saving checkpoints for 18216 into training/model.ckpt.
# WARNING:tensorflow:Entity <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7f
saving dict for global step 100000: DetectionBoxes_Precision/mAP = 0.5096619, DetectionBoxes_Precision/mAP (large) = 0.64103067, DetectionBoxes_Precision/mAP (medium) = 0.5107918, DetectionBoxes_Precision/mAP (small) = 0.35706562, DetectionBoxes_Precision/mAP@.50IOU = 0.9183829, DetectionBoxes_Precision/mAP@.75IOU = 0.48178023, DetectionBoxes_Recall/AR@1 = 0.42043105, DetectionBoxes_Recall/AR@10 = 0.5926552, DetectionBoxes_Recall/AR@100 = 0.5982586, DetectionBoxes_Recall/AR@100 (large) = 0.70625, DetectionBoxes_Recall/AR@100 (medium) = 0.5975495, DetectionBoxes_Recall/AR@100 (small) = 0.37, Loss/classification_loss = 5.2636013, Loss/localization_loss = 0.79882216, Loss/regularization_loss = 0.32707778, Loss/total_loss = 6.3894997, global_step = 100000, learning_rate = 0.004, loss = 6.3894997
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100000: training/model.ckpt-100000
# I0622 02:23:25.024250 140651608708992 estimator.py:2109] Saving 'checkpoint_path' summary for global step 100000: training/model.ckpt-100000
# INFO:tensorflow:Performing the final export in the end of training.
# I0622 02:23:25.025310 140651608708992 exporter.py:410] Performing the final export in the end of training.
# INFO:tensorflow:Calling model_fn.
# I0622 02:23:25.277144 140651608708992 estimator.py:1148] Calling model_fn.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0622 02:23:27.208508 140651608708992 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0622 02:23:27.235896 140651608708992 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0622 02:23:27.262699 140651608708992 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0622 02:23:27.289210 140651608708992 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0622 02:23:27.315647 140651608708992 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0622 02:23:27.342276 140651608708992 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:Done calling model_fn.
# I0622 02:23:27.956590 140651608708992 estimator.py:1150] Done calling model_fn.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0622 02:23:27.956879 140651608708992 deprecation.py:323] From /tensorflow-1.15.2/python3.6/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# I0622 02:23:27.957540 140651608708992 export_utils.py:170] Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# I0622 02:23:27.957668 140651608708992 export_utils.py:170] Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# I0622 02:23:27.957750 140651608708992 export_utils.py:170] Signatures INCLUDED in export for Predict: ['tensorflow/serving/predict', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# I0622 02:23:27.957826 140651608708992 export_utils.py:170] Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# I0622 02:23:27.957890 140651608708992 export_utils.py:170] Signatures INCLUDED in export for Eval: None
# 2020-06-22 02:23:27.958399: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-22 02:23:27.958896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-06-22 02:23:27.958981: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-06-22 02:23:27.959011: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-06-22 02:23:27.959033: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-06-22 02:23:27.959059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-06-22 02:23:27.959083: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-06-22 02:23:27.959103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-06-22 02:23:27.959122: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-22 02:23:27.959236: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-22 02:23:27.959703: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-22 02:23:27.960135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-06-22 02:23:27.960188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-06-22 02:23:27.960203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-06-22 02:23:27.960212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-06-22 02:23:27.960306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-22 02:23:27.960769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-22 02:23:27.961196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# INFO:tensorflow:Restoring parameters from training/model.ckpt-100000
# I0622 02:23:27.964581 140651608708992 saver.py:1284] Restoring parameters from training/model.ckpt-100000
# INFO:tensorflow:Assets added to graph.
# I0622 02:23:28.428028 140651608708992 builder_impl.py:665] Assets added to graph.
# INFO:tensorflow:No assets to write.
# I0622 02:23:28.428278 140651608708992 builder_impl.py:460] No assets to write.
# INFO:tensorflow:SavedModel written to: training/export/Servo/temp-b'1592792605'/saved_model.pb
# I0622 02:23:29.636063 140651608708992 builder_impl.py:425] SavedModel written to: training/export/Servo/temp-b'1592792605'/saved_model.pb
# INFO:tensorflow:Loss for final step: 3.8222015.
# I0622 02:23:29.990008 140651608708992 estimator.py:371] Loss for final step: 3.8222015.

# %%
# by Chengwei
#dir where the model will be saved
output_directory = './fine_tuned_model'

lst = os.listdir('training')
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join('training', last_model)

# %%
# !python /gdrive/'My Drive'/object_detection/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path=/gdrive/My\ Drive/object_detection/models/research/object_detection/samples/configs/ssd_mobilenet_v2_coco.config \
    --output_directory=/gdrive/My\ Drive/object_detection/models/research/trainedfirst \
    --trained_checkpoint_prefix=/gdrive/My\ Drive/object_detection/models/research/training/model.ckpt-100000

# %%
# !set CONFIG_FILE=/gdrive/My\ Drive/object_detection/models/research/object_detection/samples/configs/ssd_mobilenet_v2_coco.config
# !set CHECKPOINT_PATH=/gdrive/My\ Drive/object_detection/models/research/training/model.ckpt-100000
# !set OUTPUT_DIR=/gdrive/My\ Drive/object_detection/models/research/TFLite

# %%
# %cd /gdrive/My Drive/object_detection/models/research/object_detection
# Out:
# /gdrive/My Drive/object_detection/models/research/object_detection

# %%
# !python export_tflite_ssd_graph.py --pipeline_config_path=%CONFIG_FILE% --trained_checkpoint_prefix=%CHECKPOINT_PATH% --output_directory=%OUTPUT_DIR% --add_postprocessing_op=true
# Out:
# Traceback (most recent call last):
#   File "export_tflite_ssd_graph.py", line 97, in <module>
#     from object_detection import export_tflite_ssd_graph_lib
# ModuleNotFoundError: No module named 'object_detection'
